# %%
#!/data2/zhoujb/anaconda3/envs/PyTorchTabular/bin/python
import os, pickle, logging, pickle, joblib, sys, warnings
warnings.simplefilter('ignore')
from scipy import stats
import numpy as np
import pandas as pd
from sklearn import metrics, model_selection, preprocessing, feature_selection

import torch
from tabpfn import TabPFNRegressor

from mpire import WorkerPool

from scipy.stats import spearmanr

RAW_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/rawData/"
OUT_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/fs_PL/"

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)-8s %(message)s',
    datefmt='%m-%d %H:%M:%S',
    stream=sys.stderr)

# %%
def _get_tabPFN_test_score(feat_col):

    # Read data
    raw_data = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)
    # set target
    target_col = ['HZ-PL']
    raw_data = raw_data.dropna(subset=target_col)
    
    kf = model_selection.KFold(n_splits=5, shuffle=True,  random_state=0)
    y_test_final, y_pred_final = [], []
    for i, (train_index, test_index) in enumerate(kf.split(raw_data)):
        data_train = raw_data.iloc[train_index].copy()
        data_test = raw_data.iloc[test_index].copy()

        scale_tool = preprocessing.StandardScaler()
        scale_tool.fit(data_train.loc[:, feat_col])
        data_train.loc[:, feat_col] = scale_tool.transform(data_train.loc[:, feat_col])
        data_test.loc[:, feat_col] = scale_tool.transform(data_test.loc[:, feat_col])

        X_train = data_train[feat_col].copy()
        y_train = data_train[target_col].values.ravel()

        X_test = data_test[feat_col].copy()
        y_test = data_test[target_col].values.ravel()
        
        os.environ["TABPFN_MODEL_CACHE_DIR"] = "/data2/zhoujb/package/tabpfn_ckpt"
        if len(feat_col) > 500:
            clf_model =  TabPFNRegressor(device="cpu", random_state=0, n_jobs=-1, ignore_pretraining_limits=True)
        else:
            clf_model =  TabPFNRegressor(device="cpu", random_state=0, n_jobs=-1, ignore_pretraining_limits=False) 
            
        # Fit model
        clf_model.fit(X_train, y_train)
        
        y_pred = clf_model.predict(X_test)
        y_test_final.extend(y_test)
        y_pred_final.extend(y_pred)

    #score_rmse = round(metrics.root_mean_squared_error(y_test_final, y_pred_final), 4)
    score_pear = round(spearmanr(y_test_final, y_pred_final)[0], 4)

    #return score_rmse
    return score_pear

def _get_feat_and_score(k): 
    # Read data
    raw_data_1 = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)
    feat_col_1 = [x for x in raw_data_1.columns if x.startswith("fea_")]
    # Get target
    target_col = ['HZ-PL']
    raw_data_1 = raw_data_1.dropna(subset=target_col)

    X_1 = raw_data_1[feat_col_1].copy()
    X_1 = X_1.fillna(-999)
    y_1 = raw_data_1[target_col].values.ravel()

    selector = feature_selection.SelectKBest(score_func=feature_selection.f_regression, k=k)
    _ = selector.fit_transform(X_1, y_1)

    feat_sel_list = X_1.columns[selector.get_support()]

    #score_rmse = _get_tabPFN_test_score(feat_sel_list)
    score_pear = _get_tabPFN_test_score(feat_sel_list)
    #return feat_sel_list, score_rmse
    return feat_sel_list, score_pear

if __name__ == "__main__":
    best_num = 1
    #best_score_flag = np.inf
    best_score_flag = 0
    
    # Read data
    raw_data_2 = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)
    feat_col_2 = [x for x in raw_data_2.columns if x.startswith("fea_")]

    need_run_list = list(range(1, len(feat_col_2)//2)) + list(range(len(feat_col_2)//2, len(feat_col_2), 50))
    for i in need_run_list:
        #feat_sel_list, score_rmse = _get_feat_and_score(i)
        feat_sel_list, score_pear = _get_feat_and_score(i)
        #if score_rmse < best_score_flag:
        if score_pear > best_score_flag:
            #best_score_flag = score_rmse
            best_score_flag = score_pear
            best_num = i
            best_features = feat_sel_list
        logging.info("Round {}: Score:{}, best score:{}({})".format(i, 
                                                                    score_pear,
                                                                    best_score_flag,
                                                                    best_num))
    #if score_rmse < best_score_flag:
    if score_pear > best_score_flag:
        best_score_flag = score_pear
        #best_score_flag = score_rmse
        best_num = i
        best_features = feat_sel_list
    logging.info("Round {}: Score:{}, best score:{}({})".format(i, 
                                                                score_pear,
                                                                best_score_flag,
                                                                best_num))

    with open(os.path.join(OUT_PATH, "tabPFN_rfa_cv_pl_rmse"), "w") as feat_f:
        for item in best_features:
            print(item, file=feat_f)
        
    logging.info("JOB DONE")
# Out:
# 05-08 17:32:32 INFO     Round 1: Score:0.1146, best score:0.1146(1)
# 05-08 17:32:54 INFO     Round 2: Score:0.3357, best score:0.3357(2)
# 05-08 17:33:18 INFO     Round 3: Score:0.3432, best score:0.3432(3)
# 05-08 17:33:43 INFO     Round 4: Score:0.3629, best score:0.3629(4)
# 05-08 17:34:09 INFO     Round 5: Score:0.459, best score:0.459(5)
# 05-08 17:34:37 INFO     Round 6: Score:0.572, best score:0.572(6)
# 05-08 17:35:06 INFO     Round 7: Score:0.5659, best score:0.572(6)
# 05-08 17:35:41 INFO     Round 8: Score:0.568, best score:0.572(6)
# 05-08 17:36:14 INFO     Round 9: Score:0.5907, best score:0.5907(9)
# 05-08 17:36:48 INFO     Round 10: Score:0.6259, best score:0.6259(10)
# 05-08 17:37:21 INFO     Round 11: Score:0.6292, best score:0.6292(11)
# 05-08 17:37:58 INFO     Round 12: Score:0.6319, best score:0.6319(12)
# 05-08 17:38:34 INFO     Round 13: Score:0.6289, best score:0.6319(12)
# 05-08 17:39:14 INFO     Round 14: Score:0.6337, best score:0.6337(14)
# 05-08 17:39:51 INFO     Round 15: Score:0.6253, best score:0.6337(14)
# 05-08 17:40:29 INFO     Round 16: Score:0.6552, best score:0.6552(16)
# 05-08 17:41:09 INFO     Round 17: Score:0.6656, best score:0.6656(17)
# 05-08 17:41:47 INFO     Round 18: Score:0.6653, best score:0.6656(17)
# 05-08 17:42:27 INFO     Round 19: Score:0.6876, best score:0.6876(19)
# 05-08 17:43:09 INFO     Round 20: Score:0.6883, best score:0.6883(20)
# 05-08 17:43:51 INFO     Round 21: Score:0.707, best score:0.707(21)
# 05-08 17:44:34 INFO     Round 22: Score:0.7234, best score:0.7234(22)
# 05-08 17:45:18 INFO     Round 23: Score:0.7291, best score:0.7291(23)
# 05-08 17:46:02 INFO     Round 24: Score:0.7264, best score:0.7291(23)
# 05-08 17:46:47 INFO     Round 25: Score:0.7358, best score:0.7358(25)
# 05-08 17:47:33 INFO     Round 26: Score:0.7413, best score:0.7413(26)
# 05-08 17:48:22 INFO     Round 27: Score:0.7334, best score:0.7413(26)
# 05-08 17:49:09 INFO     Round 28: Score:0.7367, best score:0.7413(26)
# 05-08 17:49:59 INFO     Round 29: Score:0.7406, best score:0.7413(26)
# 05-08 17:50:48 INFO     Round 30: Score:0.7433, best score:0.7433(30)
# 05-08 17:51:38 INFO     Round 31: Score:0.7468, best score:0.7468(31)
# 05-08 17:52:26 INFO     Round 32: Score:0.7465, best score:0.7468(31)
# 05-08 17:53:14 INFO     Round 33: Score:0.7475, best score:0.7475(33)
# 05-08 17:54:04 INFO     Round 34: Score:0.7516, best score:0.7516(34)
# 05-08 17:54:56 INFO     Round 35: Score:0.7529, best score:0.7529(35)
# 05-08 17:55:50 INFO     Round 36: Score:0.7512, best score:0.7529(35)
# 05-08 17:56:42 INFO     Round 37: Score:0.7571, best score:0.7571(37)
# 05-08 17:57:36 INFO     Round 38: Score:0.7536, best score:0.7571(37)
# 05-08 17:58:30 INFO     Round 39: Score:0.7633, best score:0.7633(39)
# 05-08 17:59:24 INFO     Round 40: Score:0.7631, best score:0.7633(39)
# 05-08 18:00:18 INFO     Round 41: Score:0.7611, best score:0.7633(39)
# 05-08 18:01:13 INFO     Round 42: Score:0.7627, best score:0.7633(39)
# 05-08 18:02:10 INFO     Round 43: Score:0.7643, best score:0.7643(43)
# 05-08 18:03:08 INFO     Round 44: Score:0.7613, best score:0.7643(43)
# 05-08 18:04:07 INFO     Round 45: Score:0.7558, best score:0.7643(43)
# 05-08 18:05:06 INFO     Round 46: Score:0.7709, best score:0.7709(46)
# 05-08 18:06:04 INFO     Round 47: Score:0.7592, best score:0.7709(46)
# 05-08 18:07:06 INFO     Round 48: Score:0.7601, best score:0.7709(46)
# 05-08 18:08:11 INFO     Round 49: Score:0.7522, best score:0.7709(46)
# 05-08 18:09:18 INFO     Round 50: Score:0.7579, best score:0.7709(46)
# 05-08 18:10:30 INFO     Round 51: Score:0.7542, best score:0.7709(46)
# 05-08 18:11:44 INFO     Round 52: Score:0.7583, best score:0.7709(46)
# 05-08 18:13:00 INFO     Round 53: Score:0.7573, best score:0.7709(46)
# 05-08 18:14:17 INFO     Round 54: Score:0.7574, best score:0.7709(46)
# 05-08 18:15:34 INFO     Round 55: Score:0.7553, best score:0.7709(46)
# 05-08 18:16:55 INFO     Round 56: Score:0.7899, best score:0.7899(56)
# 05-08 18:18:18 INFO     Round 57: Score:0.7908, best score:0.7908(57)
# 05-08 18:19:45 INFO     Round 58: Score:0.7861, best score:0.7908(57)
# 05-08 18:21:10 INFO     Round 59: Score:0.7881, best score:0.7908(57)
# 05-08 18:22:36 INFO     Round 60: Score:0.788, best score:0.7908(57)
# 05-08 18:24:03 INFO     Round 61: Score:0.7894, best score:0.7908(57)
# 05-08 18:25:30 INFO     Round 62: Score:0.7875, best score:0.7908(57)
# 05-08 18:26:59 INFO     Round 63: Score:0.7913, best score:0.7913(63)
# 05-08 18:28:28 INFO     Round 64: Score:0.7881, best score:0.7913(63)
# 05-08 18:29:59 INFO     Round 65: Score:0.7933, best score:0.7933(65)
# 05-08 18:31:31 INFO     Round 66: Score:0.7925, best score:0.7933(65)
# 05-08 18:33:05 INFO     Round 67: Score:0.7955, best score:0.7955(67)
# 05-08 18:34:34 INFO     Round 68: Score:0.7906, best score:0.7955(67)
# 05-08 18:35:55 INFO     Round 69: Score:0.7941, best score:0.7955(67)
# 05-08 18:37:17 INFO     Round 70: Score:0.7903, best score:0.7955(67)
# 05-08 18:38:38 INFO     Round 71: Score:0.7945, best score:0.7955(67)
# 05-08 18:39:59 INFO     Round 72: Score:0.7934, best score:0.7955(67)
# 05-08 18:41:17 INFO     Round 73: Score:0.7909, best score:0.7955(67)
# 05-08 18:42:35 INFO     Round 74: Score:0.7956, best score:0.7956(74)
# 05-08 18:43:49 INFO     Round 75: Score:0.7935, best score:0.7956(74)
# 05-08 18:45:05 INFO     Round 76: Score:0.7953, best score:0.7956(74)
# 05-08 18:46:20 INFO     Round 77: Score:0.7964, best score:0.7964(77)
# 05-08 18:47:36 INFO     Round 78: Score:0.7942, best score:0.7964(77)
# 05-08 18:48:53 INFO     Round 79: Score:0.7949, best score:0.7964(77)
# 05-08 18:50:13 INFO     Round 80: Score:0.7937, best score:0.7964(77)
# 05-08 18:51:34 INFO     Round 81: Score:0.7922, best score:0.7964(77)
# 05-08 18:52:57 INFO     Round 82: Score:0.7949, best score:0.7964(77)
# 05-08 18:54:18 INFO     Round 83: Score:0.7922, best score:0.7964(77)
# 05-08 18:55:37 INFO     Round 84: Score:0.7963, best score:0.7964(77)
# 05-08 18:56:57 INFO     Round 85: Score:0.7935, best score:0.7964(77)
# 05-08 18:58:17 INFO     Round 86: Score:0.7956, best score:0.7964(77)
# 05-08 18:59:42 INFO     Round 87: Score:0.793, best score:0.7964(77)
# 05-08 19:01:09 INFO     Round 88: Score:0.7945, best score:0.7964(77)
# 05-08 19:02:35 INFO     Round 89: Score:0.7948, best score:0.7964(77)
# 05-08 19:04:04 INFO     Round 90: Score:0.7988, best score:0.7988(90)
# 05-08 19:05:30 INFO     Round 91: Score:0.8143, best score:0.8143(91)
# 05-08 19:06:59 INFO     Round 92: Score:0.8139, best score:0.8143(91)
# 05-08 19:08:24 INFO     Round 93: Score:0.8157, best score:0.8157(93)
# 05-08 19:09:49 INFO     Round 94: Score:0.8161, best score:0.8161(94)
# 05-08 19:11:16 INFO     Round 95: Score:0.8174, best score:0.8174(95)
# 05-08 19:12:46 INFO     Round 96: Score:0.8113, best score:0.8174(95)
# 05-08 19:14:15 INFO     Round 97: Score:0.8122, best score:0.8174(95)
# 05-08 19:15:53 INFO     Round 98: Score:0.8123, best score:0.8174(95)
# 05-08 19:17:25 INFO     Round 99: Score:0.8124, best score:0.8174(95)
# 05-08 19:18:57 INFO     Round 100: Score:0.8091, best score:0.8174(95)
# 05-08 19:20:24 INFO     Round 101: Score:0.8122, best score:0.8174(95)
# 05-08 19:21:53 INFO     Round 102: Score:0.8112, best score:0.8174(95)
# 05-08 19:23:20 INFO     Round 103: Score:0.8104, best score:0.8174(95)
# 05-08 19:24:54 INFO     Round 104: Score:0.8089, best score:0.8174(95)
# 05-08 19:26:28 INFO     Round 105: Score:0.8091, best score:0.8174(95)
# 05-08 19:27:59 INFO     Round 106: Score:0.8126, best score:0.8174(95)
# 05-08 19:29:30 INFO     Round 107: Score:0.8122, best score:0.8174(95)
# 05-08 19:31:03 INFO     Round 108: Score:0.8114, best score:0.8174(95)
# 05-08 19:32:36 INFO     Round 109: Score:0.8091, best score:0.8174(95)
# 05-08 19:34:11 INFO     Round 110: Score:0.8166, best score:0.8174(95)
# 05-08 19:35:50 INFO     Round 111: Score:0.8163, best score:0.8174(95)
# 05-08 19:37:27 INFO     Round 112: Score:0.8119, best score:0.8174(95)
# 05-08 19:39:05 INFO     Round 113: Score:0.8107, best score:0.8174(95)
# 05-08 19:40:38 INFO     Round 114: Score:0.8096, best score:0.8174(95)
# 05-08 19:42:12 INFO     Round 115: Score:0.8164, best score:0.8174(95)
# 05-08 19:43:50 INFO     Round 116: Score:0.8137, best score:0.8174(95)
# 05-08 19:45:27 INFO     Round 117: Score:0.8126, best score:0.8174(95)
# 05-08 19:47:09 INFO     Round 118: Score:0.8146, best score:0.8174(95)
# 05-08 19:48:55 INFO     Round 119: Score:0.8124, best score:0.8174(95)
# 05-08 19:50:46 INFO     Round 120: Score:0.8165, best score:0.8174(95)
# 05-08 19:52:34 INFO     Round 121: Score:0.8176, best score:0.8176(121)
# 05-08 19:54:13 INFO     Round 122: Score:0.8134, best score:0.8176(121)
# 05-08 19:55:56 INFO     Round 123: Score:0.8172, best score:0.8176(121)
# 05-08 19:57:39 INFO     Round 124: Score:0.8148, best score:0.8176(121)
# 05-08 19:59:20 INFO     Round 125: Score:0.8167, best score:0.8176(121)
# 05-08 20:01:01 INFO     Round 126: Score:0.8163, best score:0.8176(121)
# 05-08 20:02:51 INFO     Round 127: Score:0.8142, best score:0.8176(121)
# 05-08 20:04:45 INFO     Round 128: Score:0.8171, best score:0.8176(121)
# 05-08 20:06:35 INFO     Round 129: Score:0.8184, best score:0.8184(129)
# 05-08 20:08:25 INFO     Round 130: Score:0.8189, best score:0.8189(130)
# 05-08 20:10:09 INFO     Round 131: Score:0.8192, best score:0.8192(131)
# 05-08 20:11:59 INFO     Round 132: Score:0.8184, best score:0.8192(131)
# 05-08 20:13:46 INFO     Round 133: Score:0.8155, best score:0.8192(131)
# 05-08 20:15:35 INFO     Round 134: Score:0.8175, best score:0.8192(131)
# 05-08 20:17:31 INFO     Round 135: Score:0.8175, best score:0.8192(131)
# 05-08 20:19:30 INFO     Round 136: Score:0.8165, best score:0.8192(131)
# 05-08 20:21:28 INFO     Round 137: Score:0.8143, best score:0.8192(131)
# 05-08 20:23:23 INFO     Round 138: Score:0.8193, best score:0.8193(138)
# 05-08 20:25:18 INFO     Round 139: Score:0.8155, best score:0.8193(138)
# 05-08 20:27:21 INFO     Round 140: Score:0.8169, best score:0.8193(138)
# 05-08 20:29:15 INFO     Round 141: Score:0.814, best score:0.8193(138)
# 05-08 20:31:18 INFO     Round 142: Score:0.8128, best score:0.8193(138)
# 05-08 20:33:17 INFO     Round 143: Score:0.815, best score:0.8193(138)
# 05-08 20:35:16 INFO     Round 144: Score:0.8174, best score:0.8193(138)
# 05-08 20:37:12 INFO     Round 145: Score:0.8147, best score:0.8193(138)
# 05-08 20:39:18 INFO     Round 146: Score:0.8146, best score:0.8193(138)
# 05-08 20:41:25 INFO     Round 147: Score:0.8147, best score:0.8193(138)
# 05-08 20:43:29 INFO     Round 148: Score:0.8144, best score:0.8193(138)
# 05-08 20:45:27 INFO     Round 149: Score:0.8127, best score:0.8193(138)
# 05-08 20:47:22 INFO     Round 150: Score:0.8163, best score:0.8193(138)
# 05-08 20:49:14 INFO     Round 151: Score:0.8142, best score:0.8193(138)
# 05-08 20:51:16 INFO     Round 152: Score:0.8168, best score:0.8193(138)
# 05-08 20:53:16 INFO     Round 153: Score:0.832, best score:0.832(153)
# 05-08 20:55:15 INFO     Round 154: Score:0.836, best score:0.836(154)
# 05-08 20:57:12 INFO     Round 155: Score:0.8356, best score:0.836(154)
# 05-08 20:59:22 INFO     Round 156: Score:0.8389, best score:0.8389(156)
# 05-08 21:01:37 INFO     Round 157: Score:0.8377, best score:0.8389(156)
# 05-08 21:03:41 INFO     Round 158: Score:0.8309, best score:0.8389(156)
# 05-08 21:05:47 INFO     Round 159: Score:0.8317, best score:0.8389(156)
# 05-08 21:08:00 INFO     Round 160: Score:0.8305, best score:0.8389(156)
# 05-08 21:10:23 INFO     Round 161: Score:0.8322, best score:0.8389(156)
# 05-08 21:12:58 INFO     Round 162: Score:0.8342, best score:0.8389(156)
# 05-08 21:15:32 INFO     Round 163: Score:0.8299, best score:0.8389(156)
# 05-08 21:18:28 INFO     Round 164: Score:0.8339, best score:0.8389(156)
# 05-08 21:21:25 INFO     Round 165: Score:0.8258, best score:0.8389(156)
# 05-08 21:24:08 INFO     Round 166: Score:0.8243, best score:0.8389(156)
# 05-08 21:27:10 INFO     Round 167: Score:0.8272, best score:0.8389(156)
# 05-08 21:30:22 INFO     Round 168: Score:0.8246, best score:0.8389(156)
# 05-08 21:34:07 INFO     Round 169: Score:0.825, best score:0.8389(156)
# 05-08 21:38:02 INFO     Round 170: Score:0.828, best score:0.8389(156)
# 05-08 21:41:56 INFO     Round 171: Score:0.827, best score:0.8389(156)
# 05-08 21:46:17 INFO     Round 172: Score:0.8268, best score:0.8389(156)
# 05-08 21:50:36 INFO     Round 173: Score:0.8248, best score:0.8389(156)
# 05-08 21:54:47 INFO     Round 174: Score:0.8244, best score:0.8389(156)
# 05-08 21:58:22 INFO     Round 175: Score:0.8239, best score:0.8389(156)
# 05-08 22:01:57 INFO     Round 176: Score:0.8263, best score:0.8389(156)
# 05-08 22:05:53 INFO     Round 177: Score:0.8298, best score:0.8389(156)
# 05-08 22:10:13 INFO     Round 178: Score:0.8284, best score:0.8389(156)
# 05-08 22:14:44 INFO     Round 179: Score:0.8294, best score:0.8389(156)
# 05-08 22:18:57 INFO     Round 180: Score:0.8269, best score:0.8389(156)
# 05-08 22:23:32 INFO     Round 181: Score:0.8282, best score:0.8389(156)
# 05-08 22:28:11 INFO     Round 182: Score:0.8285, best score:0.8389(156)
# 05-08 22:32:53 INFO     Round 183: Score:0.8328, best score:0.8389(156)
# 05-08 22:37:31 INFO     Round 184: Score:0.8342, best score:0.8389(156)
# 05-08 22:41:44 INFO     Round 185: Score:0.8305, best score:0.8389(156)
# 05-08 22:45:57 INFO     Round 186: Score:0.8331, best score:0.8389(156)
# 05-08 22:50:22 INFO     Round 187: Score:0.8302, best score:0.8389(156)
# 05-08 22:54:49 INFO     Round 188: Score:0.8331, best score:0.8389(156)
# 05-08 22:59:19 INFO     Round 189: Score:0.8309, best score:0.8389(156)
# 05-08 23:03:52 INFO     Round 190: Score:0.8362, best score:0.8389(156)
# 05-08 23:08:25 INFO     Round 191: Score:0.8316, best score:0.8389(156)
# 05-08 23:12:56 INFO     Round 192: Score:0.833, best score:0.8389(156)
# 05-08 23:17:28 INFO     Round 193: Score:0.832, best score:0.8389(156)
# 05-08 23:22:04 INFO     Round 194: Score:0.8335, best score:0.8389(156)
# 05-08 23:26:39 INFO     Round 195: Score:0.833, best score:0.8389(156)
# 05-08 23:31:20 INFO     Round 196: Score:0.8293, best score:0.8389(156)
# 05-08 23:36:00 INFO     Round 197: Score:0.8295, best score:0.8389(156)
# 05-08 23:40:46 INFO     Round 198: Score:0.8316, best score:0.8389(156)
# 05-08 23:45:33 INFO     Round 199: Score:0.8321, best score:0.8389(156)
# 05-08 23:50:21 INFO     Round 200: Score:0.8301, best score:0.8389(156)
# 05-08 23:55:18 INFO     Round 201: Score:0.8298, best score:0.8389(156)
# 05-09 00:00:19 INFO     Round 202: Score:0.8289, best score:0.8389(156)
# 05-09 00:05:11 INFO     Round 203: Score:0.8281, best score:0.8389(156)
# 05-09 00:10:11 INFO     Round 204: Score:0.8285, best score:0.8389(156)
# 05-09 00:15:21 INFO     Round 205: Score:0.8281, best score:0.8389(156)
# 05-09 00:20:30 INFO     Round 206: Score:0.8271, best score:0.8389(156)
# 05-09 00:25:26 INFO     Round 207: Score:0.8236, best score:0.8389(156)
# 05-09 00:30:30 INFO     Round 208: Score:0.8281, best score:0.8389(156)
# 05-09 00:35:46 INFO     Round 209: Score:0.8245, best score:0.8389(156)
# 05-09 00:41:06 INFO     Round 210: Score:0.8269, best score:0.8389(156)
# 05-09 00:46:23 INFO     Round 211: Score:0.8243, best score:0.8389(156)
# 05-09 00:51:39 INFO     Round 212: Score:0.8268, best score:0.8389(156)
# 05-09 00:56:47 INFO     Round 213: Score:0.8265, best score:0.8389(156)
# 05-09 01:01:54 INFO     Round 214: Score:0.8279, best score:0.8389(156)
# 05-09 01:07:01 INFO     Round 215: Score:0.8252, best score:0.8389(156)
# 05-09 01:12:13 INFO     Round 216: Score:0.8259, best score:0.8389(156)
# 05-09 01:17:42 INFO     Round 217: Score:0.8242, best score:0.8389(156)
# 05-09 01:23:06 INFO     Round 218: Score:0.8263, best score:0.8389(156)
# 05-09 01:28:39 INFO     Round 219: Score:0.824, best score:0.8389(156)
# 05-09 01:34:07 INFO     Round 220: Score:0.8242, best score:0.8389(156)
# 05-09 01:39:39 INFO     Round 221: Score:0.8227, best score:0.8389(156)
# 05-09 01:45:14 INFO     Round 222: Score:0.826, best score:0.8389(156)
# 05-09 01:50:56 INFO     Round 223: Score:0.8368, best score:0.8389(156)
# 05-09 01:56:48 INFO     Round 224: Score:0.8336, best score:0.8389(156)
# 05-09 02:02:42 INFO     Round 225: Score:0.8374, best score:0.8389(156)
# 05-09 02:08:35 INFO     Round 226: Score:0.8341, best score:0.8389(156)
# 05-09 02:14:30 INFO     Round 227: Score:0.8345, best score:0.8389(156)
# 05-09 02:20:26 INFO     Round 228: Score:0.8293, best score:0.8389(156)
# 05-09 02:26:19 INFO     Round 229: Score:0.8355, best score:0.8389(156)
# 05-09 02:32:13 INFO     Round 230: Score:0.8335, best score:0.8389(156)
# 05-09 02:38:09 INFO     Round 231: Score:0.8344, best score:0.8389(156)
# 05-09 02:44:17 INFO     Round 232: Score:0.834, best score:0.8389(156)
# 05-09 02:50:12 INFO     Round 233: Score:0.8342, best score:0.8389(156)
# 05-09 02:56:06 INFO     Round 234: Score:0.8364, best score:0.8389(156)
# 05-09 03:02:00 INFO     Round 235: Score:0.8365, best score:0.8389(156)
# 05-09 03:08:11 INFO     Round 236: Score:0.8375, best score:0.8389(156)
# 05-09 03:14:50 INFO     Round 237: Score:0.8334, best score:0.8389(156)
# 05-09 03:21:34 INFO     Round 238: Score:0.8363, best score:0.8389(156)
# 05-09 03:27:58 INFO     Round 239: Score:0.8376, best score:0.8389(156)
# 05-09 03:34:22 INFO     Round 240: Score:0.8343, best score:0.8389(156)
# 05-09 03:40:49 INFO     Round 241: Score:0.8349, best score:0.8389(156)
# 05-09 03:47:28 INFO     Round 242: Score:0.837, best score:0.8389(156)
# 05-09 03:53:56 INFO     Round 243: Score:0.8355, best score:0.8389(156)
# 05-09 04:00:59 INFO     Round 244: Score:0.8312, best score:0.8389(156)
# 05-09 04:08:13 INFO     Round 245: Score:0.8379, best score:0.8389(156)
# 05-09 04:15:10 INFO     Round 246: Score:0.837, best score:0.8389(156)
# 05-09 04:22:08 INFO     Round 247: Score:0.8327, best score:0.8389(156)
# 05-09 04:29:14 INFO     Round 248: Score:0.8351, best score:0.8389(156)
# 05-09 04:36:22 INFO     Round 249: Score:0.8326, best score:0.8389(156)
# 05-09 04:43:40 INFO     Round 250: Score:0.8348, best score:0.8389(156)
# 05-09 04:50:53 INFO     Round 251: Score:0.8325, best score:0.8389(156)
# 05-09 04:58:16 INFO     Round 252: Score:0.8362, best score:0.8389(156)
# 05-09 05:05:37 INFO     Round 253: Score:0.8301, best score:0.8389(156)
# 05-09 05:13:07 INFO     Round 254: Score:0.8275, best score:0.8389(156)
# 05-09 05:20:37 INFO     Round 255: Score:0.828, best score:0.8389(156)
# 05-09 05:28:20 INFO     Round 256: Score:0.829, best score:0.8389(156)
# 05-09 05:35:57 INFO     Round 257: Score:0.8309, best score:0.8389(156)
# 05-09 05:43:39 INFO     Round 258: Score:0.8286, best score:0.8389(156)
# 05-09 05:51:09 INFO     Round 259: Score:0.8281, best score:0.8389(156)
# 05-09 05:58:29 INFO     Round 260: Score:0.8316, best score:0.8389(156)
# 05-09 06:06:14 INFO     Round 261: Score:0.8252, best score:0.8389(156)
# 05-09 06:13:35 INFO     Round 262: Score:0.8283, best score:0.8389(156)
# 05-09 06:20:33 INFO     Round 263: Score:0.8277, best score:0.8389(156)
# 05-09 06:27:35 INFO     Round 264: Score:0.8253, best score:0.8389(156)
# 05-09 06:34:28 INFO     Round 265: Score:0.8265, best score:0.8389(156)
# 05-09 06:41:31 INFO     Round 266: Score:0.8295, best score:0.8389(156)
# 05-09 06:48:30 INFO     Round 267: Score:0.8295, best score:0.8389(156)
# 05-09 06:55:28 INFO     Round 268: Score:0.8284, best score:0.8389(156)
# 05-09 07:02:35 INFO     Round 269: Score:0.8288, best score:0.8389(156)
# 05-09 07:09:39 INFO     Round 270: Score:0.828, best score:0.8389(156)
# 05-09 07:16:46 INFO     Round 271: Score:0.8261, best score:0.8389(156)
# 05-09 07:23:51 INFO     Round 272: Score:0.8263, best score:0.8389(156)
# 05-09 07:31:03 INFO     Round 273: Score:0.8263, best score:0.8389(156)
# 05-09 07:38:10 INFO     Round 274: Score:0.8271, best score:0.8389(156)
# 05-09 07:45:24 INFO     Round 275: Score:0.8243, best score:0.8389(156)
# 05-09 07:52:39 INFO     Round 276: Score:0.8253, best score:0.8389(156)
# 05-09 07:59:59 INFO     Round 277: Score:0.8266, best score:0.8389(156)
# 05-09 08:07:24 INFO     Round 278: Score:0.8272, best score:0.8389(156)
# 05-09 08:14:58 INFO     Round 279: Score:0.828, best score:0.8389(156)
# 05-09 08:22:34 INFO     Round 280: Score:0.8237, best score:0.8389(156)
# 05-09 08:30:19 INFO     Round 281: Score:0.8302, best score:0.8389(156)
# 05-09 08:37:59 INFO     Round 282: Score:0.8285, best score:0.8389(156)
# 05-09 08:46:01 INFO     Round 283: Score:0.8291, best score:0.8389(156)
# 05-09 08:53:40 INFO     Round 284: Score:0.8295, best score:0.8389(156)
# 05-09 09:01:57 INFO     Round 285: Score:0.8266, best score:0.8389(156)
# 05-09 09:10:55 INFO     Round 286: Score:0.8291, best score:0.8389(156)
# 05-09 09:19:56 INFO     Round 287: Score:0.8244, best score:0.8389(156)
# 05-09 09:28:49 INFO     Round 288: Score:0.8268, best score:0.8389(156)
# 05-09 09:37:22 INFO     Round 289: Score:0.8252, best score:0.8389(156)
# 05-09 09:46:18 INFO     Round 290: Score:0.8237, best score:0.8389(156)
# 05-09 09:54:57 INFO     Round 291: Score:0.8245, best score:0.8389(156)
# 05-09 10:03:26 INFO     Round 292: Score:0.8267, best score:0.8389(156)
# 05-09 10:11:57 INFO     Round 293: Score:0.8266, best score:0.8389(156)
# 05-09 10:20:38 INFO     Round 294: Score:0.8251, best score:0.8389(156)
# 05-09 10:29:31 INFO     Round 295: Score:0.8267, best score:0.8389(156)
# 05-09 10:38:09 INFO     Round 296: Score:0.8262, best score:0.8389(156)
# 05-09 10:47:07 INFO     Round 297: Score:0.8244, best score:0.8389(156)
# 05-09 10:55:53 INFO     Round 298: Score:0.8232, best score:0.8389(156)
# 05-09 11:04:36 INFO     Round 299: Score:0.8248, best score:0.8389(156)
# 05-09 11:13:25 INFO     Round 300: Score:0.8209, best score:0.8389(156)
# 05-09 11:22:04 INFO     Round 301: Score:0.8295, best score:0.8389(156)
# 05-09 11:30:48 INFO     Round 302: Score:0.8281, best score:0.8389(156)
# 05-09 11:39:33 INFO     Round 303: Score:0.8238, best score:0.8389(156)
# 05-09 11:50:16 INFO     Round 353: Score:0.8294, best score:0.8389(156)
# 05-09 12:03:06 INFO     Round 403: Score:0.8331, best score:0.8389(156)
# 05-09 12:20:15 INFO     Round 453: Score:0.8357, best score:0.8389(156)
# 05-09 12:38:52 INFO     Round 503: Score:0.8358, best score:0.8389(156)
# 05-09 13:01:18 INFO     Round 553: Score:0.8443, best score:0.8443(553)
# 05-09 13:28:10 INFO     Round 603: Score:0.8308, best score:0.8443(553)
# 05-09 13:28:10 INFO     Round 603: Score:0.8308, best score:0.8443(553)
# 05-09 13:28:10 INFO     JOB DONE

# %%
def add_feature(indices, n_jobs=12):
    
    raw_data_1 = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)
    feat_col = [x for x in raw_data_1.columns if x.startswith("fea_")]

    new_indices = list(set(range(len(feat_col))) - set(indices))
    params_list = [[indices + [i]] for i in new_indices]

    with WorkerPool(n_jobs=n_jobs) as pool:
        scores = pool.map(_get_cb_test_score, params_list, progress_bar=False)
    
    #indices.append(new_indices[scores.index(max(scores))])
    indices.append(new_indices[scores.index(min(scores))])
    return min(scores)

if __name__ == "__main__":
    features=[]
    best_score_flag = np.inf
    raw_data_2 = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)
    all_features = np.array([x for x in raw_data_2.columns if x.startswith("fea_")])
    indices = [list(all_features).index(feature) for feature in features]

    best_num = 1
    for i in range(len(all_features)):
        score_tmp = add_feature(indices, n_jobs=6)
        feature_order_list = all_features[indices]
        if score_tmp < best_score_flag:
            best_score_flag = score_tmp
            best_features = all_features[indices]
            best_num = i + 1
    
        logging.info("Round {}: Score:{}, best score:{}({}), feature list:{}".format(i+1, score_tmp, 
                                                                                   best_score_flag, 
                                                                                     best_num,
                                                                                   feature_order_list))
        
        if (i + 1) - best_num > 10:
            break

    with open(os.path.join(OUT_PATH, "tabPFN_rfa_cv_pl_rmse"), "w") as feat_f:
        for item in best_features:
            print(item, file=feat_f)
        
    logging.info("JOB DONE")

# %%
#!/data2/zhoujb/anaconda3/envs/PyTorchTabular/bin/python
import os, pickle, logging, pickle, joblib, sys, warnings
warnings.simplefilter('ignore')
from scipy import stats
import numpy as np
import pandas as pd
from sklearn import metrics, model_selection, preprocessing

#import catboost as cb
#import lightgbm as lgb
#import shap

import torch
from tabpfn import TabPFNRegressor

RAW_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/rawData/"
OUT_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/fs_PL/"

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)-8s %(message)s',
    datefmt='%m-%d %H:%M:%S',
    stream=sys.stderr)

def getCBShapLessFeat(feat_col=None):
    
    raw_data = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)

    target_col = ['HZ-PL']
    raw_data = raw_data.dropna(subset=target_col)

    if feat_col is None:
        feat_col = [x for x in raw_data.columns if x.startswith("fea_")]

    #cat_col_names_raw = ["heading_stage_d", "leaf_blast_rep1", "leaf_blast_rep2", "leaf_blast_average", "GR_D3", "GR_D2", "GR_D1"]
    #cat_col_names_raw = ["feat_{}".format(x) for x in cat_col_names_raw]
    #cat_col_names = [i for i in feat_col if i in cat_col_names_raw]
    
    #num_col_names = [i for i in feat_col if (i.startswith("feat")) and (i not in cat_col_names)]
    #cat_col_num = []
    #for item in cat_col_names:
        #cat_col_num.append(feat_col.index(item))

    #for col in cat_col_names:
        #raw_data[col] = raw_data[col].astype("str")

    kf = model_selection.KFold(n_splits=5, shuffle=True,  random_state=0)
    y_test_final, y_pred_final = [], []
    for i, (train_index, test_index) in enumerate(kf.split(raw_data)):
        data_train = raw_data.iloc[train_index].copy()
        data_test = raw_data.iloc[test_index].copy()

        scale_tool = preprocessing.StandardScaler()
        scale_tool.fit(data_train.loc[:, feat_col])
        data_train.loc[:, feat_col] = scale_tool.transform(data_train.loc[:, feat_col])
        data_test.loc[:, feat_col] = scale_tool.transform(data_test.loc[:, feat_col])

        #train_sel = data_train.sample(frac=0.8, random_state=0)
        #val_sel = data_train.drop(train_sel.index).copy()

        #X_train = train_sel[feat_col].copy()
        #y_train = train_sel[target_col].values.ravel()

        #X_val = val_sel[feat_col].copy()
        #y_val = val_sel[target_col].values.ravel()
        
        X_train = data_train[feat_col].copy()
        y_train = data_train[target_col].values.ravel()

        X_test = data_test[feat_col].copy()
        y_test = data_test[target_col].values.ravel()
        
        
        # Initialize CatBoostClassifier
        #clf_model = cb.CatBoostRegressor(random_state=0, thread_count=4, loss_function='RMSE', verbose=0)
        os.environ["TABPFN_MODEL_CACHE_DIR"] = "/data2/zhoujb/package/tabpfn_ckpt"
        if len(feat_col) > 500:
            clf_model =  TabPFNRegressor(device="cpu", random_state=0, n_jobs=-1, ignore_pretraining_limits=True)
        else:
            clf_model =  TabPFNRegressor(device="cpu", random_state=0, n_jobs=-1, ignore_pretraining_limits=False) 
            
        # Initialize CatBoostClassifier
        #clf_model = cb.CatBoostRegressor(random_state=0, thread_count=48, loss_function='RMSE', verbose=0)

        # Fit model
        #clf_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], verbose=0, plot=False)
        clf_model.fit(X_train, y_train)

        y_pred = clf_model.predict(X_test)

        y_test_final.extend(y_test)
        y_pred_final.extend(y_pred)

        if i == 0:
            fs_val_df = pd.DataFrame(clf_model.feature_importances_, index=feat_col)
            fs_val_df = fs_val_df.rename(columns={0:i+1})
        else:
            fs_val_tmp = pd.DataFrame(clf_model.feature_importances_, index=feat_col)
            fs_val_tmp = fs_val_tmp.rename(columns={0:i+1})
            fs_val_df = pd.concat([fs_val_df, fs_val_tmp], axis=1, sort=False)

    #score_pear = pearsonr(y_test, y_pred)[0]
    #score_rmse = round(metrics.mean_squared_error(y_test_final, y_pred_final, squared=False), 4)
    #score_rmse = metrics.mean_squared_error(y_test_final, y_pred_final, squared=False)
    #score_nrmse = round(score_rmse / np.std(y_test), 4)
    score_rmse = round(metrics.root_mean_squared_error(y_test_final, y_pred_final), 4)
    
    fs_val_df_mean = fs_val_df.mean(axis=1).to_frame()
    fs_val_df_mean = fs_val_df_mean.sort_values(by=[0], ascending=False)
    less_import_feat = fs_val_df_mean.index[-1]
    return score_rmse, less_import_feat
    #return score_nrmse, less_import_feat

if __name__ == "__main__":
    min_feats = 10
    raw_data = pd.read_table(os.path.join(RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)

    feat_col = [x for x in raw_data.columns if x.startswith("fea_")]
    logging.info("Run number of features:{}".format(len(feat_col)))
    #auc_mean_flag, test_auc_flag, less_import_feat = getCBShapLessFeat()
    #auc_mean, test_auc, less_import_feat = getCBShapLessFeat()
    score_rmse, less_import_feat = getCBShapLessFeat()

    test_score_flag = score_rmse
    best_round = len(feat_col)
    feat_list_best = feat_col.copy()
    for num_feats in range(len(feat_col)-1, min_feats-1, -1):
        logging.info("Round:{}, The less important feature is: {}, test_score:{}, best_score:{}({})".format(num_feats+1, 
                                                                                                     less_import_feat,score_rmse, 
                                                                                                            test_score_flag, best_round))
        feat_col.remove(less_import_feat)
        score_rmse, less_import_feat = getCBShapLessFeat(feat_col=feat_col)
        if score_rmse < test_score_flag:
            test_score_flag = min(score_rmse, test_score_flag)
            best_round = num_feats
            feat_list_best = feat_col.copy()
        
        if best_round - num_feats > 10:
            break
            
    logging.info("Round:{}, The less important feature is: {}, test_score:{}, best_score:{}({})".format(num_feats+1, 
                                                                                                     less_import_feat,score_rmse, 
                                                                                                            test_score_flag, best_round))
    if score_rmse < test_score_flag:
        test_score_flag = min(score_rmse, test_score_flag)
        feat_list_best = feat_col.copy()

    logging.info("The number of best features:{}".format(len(feat_list_best)))
    logging.info("Best features:{}".format(feat_list_best))
    with open(os.path.join(OUT_PATH, "tabPFN_rfe_cv_pl_rmse"), "w") as feat_f:
        for item in feat_list_best:
            print(item, file=feat_f)

    logging.info("JOB DONE")
