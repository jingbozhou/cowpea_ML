# %%
import os, pickle, logging, pickle, joblib, sys, warnings, time
warnings.simplefilter('ignore')
from scipy import stats
import numpy as np
import pandas as pd

import catboost as cb
import lightgbm as lgb

from sklearn import ensemble, metrics, pipeline, preprocessing, impute, model_selection
from scipy.stats import pearsonr, spearmanr

#from shaphypetune import BoostRFE, BoostBoruta

ML_RAW_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/rawData/"
TEST_RES_PATH = "/data2/zhoujb/project/cowpea_project/basedXPXLR/ML/tesRes/"

# %%
raw_data = pd.read_table(os.path.join(ML_RAW_PATH, "raw_data_PL.txt"), sep="\t", index_col=0)

target_col = ['HZ-PL']
raw_data = raw_data.dropna(subset=target_col)

feat_col = [x for x in raw_data.columns if x.startswith("fea_")]

kf = model_selection.KFold(n_splits=5, shuffle=True,  random_state=0)
y_test_final, y_pred_final = [], []
for i, (train_index, test_index) in enumerate(kf.split(raw_data)):
    print("Round {} start...".format(i))
    start_time = time.time()
    
    data_train = raw_data.iloc[train_index].copy()
    data_test = raw_data.iloc[test_index].copy()

    scale_tool = preprocessing.StandardScaler()
    scale_tool.fit(data_train.loc[:, feat_col])
    data_train.loc[:, feat_col] = scale_tool.transform(data_train.loc[:, feat_col])
    data_test.loc[:, feat_col] = scale_tool.transform(data_test.loc[:, feat_col])

    train_sel = data_train.sample(frac=0.8, random_state=0)
    val_sel = data_train.drop(train_sel.index).copy()

    X_train = train_sel[feat_col].copy()
    y_train = train_sel[target_col].values.ravel()

    X_val = val_sel[feat_col].copy()
    y_val = val_sel[target_col].values.ravel()

    X_test = data_test[feat_col].copy()
    y_test = data_test[target_col].values.ravel()

    clf_model = lgb.LGBMRegressor(boosting_type="gbdt", n_estimators=1000, random_state=0, n_jobs=4, num_leaves=5)

    clf_model.fit(X_train, y_train, 
                  eval_set=[(X_train, y_train), (X_val, y_val)],
                  callbacks=[lgb.log_evaluation(period=10), 
                             lgb.early_stopping(stopping_rounds=10)])

    y_pred = clf_model.predict(X_test)

    y_test_final.append(y_test)
    y_pred_final.append(y_pred)

    end_time = time.time()
    print("Round {}:{}".format(i, end_time-start_time))
# Out:
# Round 0 start...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15634
# [LightGBM] [Info] Number of data points in the train set: 192, number of used features: 513
# [LightGBM] [Info] Start training from score 42.910401
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 91.646	valid_1's l2: 134.548
# [20]	training's l2: 46.1925	valid_1's l2: 103.438
# [30]	training's l2: 29.0094	valid_1's l2: 94.3917
# [40]	training's l2: 19.8148	valid_1's l2: 92.15
# [50]	training's l2: 13.8509	valid_1's l2: 90.2654
# [60]	training's l2: 9.97247	valid_1's l2: 89.2645
# [70]	training's l2: 7.28056	valid_1's l2: 87.9224
# [80]	training's l2: 5.35304	valid_1's l2: 88.3626
# Early stopping, best iteration is:
# [72]	training's l2: 6.88903	valid_1's l2: 87.3801
# Round 0:0.5794804096221924
# Round 1 start...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004015 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15679
# [LightGBM] [Info] Number of data points in the train set: 193, number of used features: 505
# [LightGBM] [Info] Start training from score 43.576455
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 79.1257	valid_1's l2: 144.836
# [20]	training's l2: 38.7452	valid_1's l2: 124.172
# [30]	training's l2: 23.3858	valid_1's l2: 126.528
# Early stopping, best iteration is:
# [24]	training's l2: 31.3514	valid_1's l2: 123.963
# Round 1:0.12753820419311523
# Round 2 start...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003927 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15677
# [LightGBM] [Info] Number of data points in the train set: 193, number of used features: 510
# [LightGBM] [Info] Start training from score 42.534779
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 78.8302	valid_1's l2: 165.916
# [20]	training's l2: 40.1405	valid_1's l2: 128.334
# [30]	training's l2: 25.4021	valid_1's l2: 115.704
# [40]	training's l2: 17.0523	valid_1's l2: 110.14
# [50]	training's l2: 11.8112	valid_1's l2: 107.32
# [60]	training's l2: 8.38969	valid_1's l2: 105.541
# Early stopping, best iteration is:
# [57]	training's l2: 9.27445	valid_1's l2: 105.062
# Round 2:0.16682147979736328
# Round 3 start...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003601 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15678
# [LightGBM] [Info] Number of data points in the train set: 193, number of used features: 510
# [LightGBM] [Info] Start training from score 43.222765
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 94.8219	valid_1's l2: 155.51
# [20]	training's l2: 49.1116	valid_1's l2: 103.024
# [30]	training's l2: 30.6434	valid_1's l2: 91.3151
# [40]	training's l2: 20.7828	valid_1's l2: 89.9028
# Early stopping, best iteration is:
# [33]	training's l2: 27.4502	valid_1's l2: 89.2846
# Round 3:0.11999344825744629
# Round 4 start...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15651
# [LightGBM] [Info] Number of data points in the train set: 193, number of used features: 495
# [LightGBM] [Info] Start training from score 43.033724
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 90.1916	valid_1's l2: 113.292
# [20]	training's l2: 42.2648	valid_1's l2: 86.468
# [30]	training's l2: 25.827	valid_1's l2: 85.4826
# [40]	training's l2: 17.3225	valid_1's l2: 84.4598
# Early stopping, best iteration is:
# [38]	training's l2: 18.7916	valid_1's l2: 83.7754
# Round 4:0.12074637413024902

# %%
res_df = pd.DataFrame(columns=["Model", "Times", "Score", "Type"])
for i in range(len(y_test_final)):
    ## Get score
    #score_pear = pearsonr(y_test_final[i], y_pred_final[i])[0]
    score_spear = spearmanr(y_test_final[i], y_pred_final[i])[0]
    score_rmse = metrics.root_mean_squared_error(y_test_final[i], y_pred_final[i])
    score_nrmse = score_rmse / np.std(y_test_final[i])

    #res_df.loc[len(res_df)] = ["LB_ALL", i+1, score_pear, "R"]
    res_df.loc[len(res_df)] = ["LB_ALL", i+1, score_spear, "R"]
    res_df.loc[len(res_df)] = ["LB_ALL", i+1, score_rmse, "RMSE"]
    res_df.loc[len(res_df)] = ["LB_ALL", i+1, score_nrmse, "NRMSE"]

with open(os.path.join(TEST_RES_PATH, "PL_LB_ALL.pickle"), "wb") as out_f:
    pickle.dump(res_df, out_f)

# %%
res_df.groupby(["Type"])["Score"].mean()
# Out:
# Type
# NRMSE    0.580845
# R        0.809853
# RMSE     9.471934
# Name: Score, dtype: float64

# %%
with open(os.path.join(TEST_RES_PATH, "PL_LB_ALL.pickle"), "rb") as f:
    res_df = pickle.load(f)

res_df
# Out:
#      Model  Times      Score   Type
# 0   LB_ALL      1   0.799016      R
# 1   LB_ALL      1   9.105753   RMSE
# 2   LB_ALL      1   0.547146  NRMSE
# 3   LB_ALL      2   0.770447      R
# 4   LB_ALL      2  11.064222   RMSE
# 5   LB_ALL      2   0.620632  NRMSE
# 6   LB_ALL      3   0.842674      R
# 7   LB_ALL      3   9.696471   RMSE
# 8   LB_ALL      3   0.595624  NRMSE
# 9   LB_ALL      4   0.746374      R
# 10  LB_ALL      4   9.201516   RMSE
# 11  LB_ALL      4   0.597544  NRMSE
# 12  LB_ALL      5   0.777937      R
# 13  LB_ALL      5   9.160522   RMSE
# 14  LB_ALL      5   0.612896  NRMSE

# %%
res_df.groupby(["Type"])["Score"].mean()
# Out:
# Type
# NRMSE    0.594768
# R        0.787290
# RMSE     9.645697
# Name: Score, dtype: float64
